# %% [markdown]
# _____________________________________________________________
# # Coursework 1 - Python Web Scraper
# _____________________________________________________________
# **Web scraping** is essentially about downloading structured data from the web, selecting some of it, and passing this to some another process. This may be incredibly handy in situations where you do not have any data available to you and want to source it from the web, or when you want to keep the track of some information appearing on it (e.g., monitoring news, stock prices, etc.).
#
# In the following coursework, you will have to exploit the knowledge you collected throughout the course in order to create a web scrapper module that you may later use to gather the data that interests you the most.
# ___________
# ## Install & Import Packages
# ___________
# You will be using `Python 3` and you will also need to install these 2 packages:
# - `requests` - for performing the HTTP requests
# - `BeautifulSoup4` - for handling the HTML processing
#
# The executable cells below will install these packages to your current conda environment and import all the necessary modules required for this coursework.
#
# `Note` Keep in mind that later you will have to move the imports to their corresponding modules. Not the installs, though, these are permament (but only for this conda environment).

# %%
# # Install a `conda package in the current Jupyter kernel
# import sys
# !conda install --yes --prefix {sys.prefix} requests
# !conda install --yes --prefix {sys.prefix} beautifulsoup4

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %% [markdown]
# ___________
# ## 01. Web Requests
# ___________
# Your first task will be to develop a set of functions that will help you to download the chosen web page content using the `requests` package and its `.get()` method.
#
# Essentially, your developed function `get_url_content(url)` should accept a single url (string) argument and make a `GET` request to that `URL`. If nothing goes wrong, you end up with the raw HTML content for the page you requested, but you should also think of any problems that may arise when making this request (e.g., bad `URL`, remote server down, etc.) and return `None` if so.
#
# You may also use `with closing(some_function) as resp: ....` in order to ensure that any network resources are freed when they go out of scope in that `with` block. That is good practice that helps to prevent fatal errors and/or network timeouts.
#
# `Important!` You may prototype with your code here, but, after you are finished, create a module (file) `scrapper.py` and move your code there. Now you can test your solution by importing your `get_url_content` method from the `scrapper` module and calling it with a URL argument:
#
#     from scrapper import get_url_content
#     raw_html = get_url_content('https://www.cnbc.com/stocks/')
#     len(raw_html)
#     600151
#
#     no_html = get_url_content('https://realpython.com/blog/nope-not-gonna-find-it')
#     no_html is None
#
# `Note` For more info/examples on `requests`, check [this documentation](https://www.w3schools.com/python/module_requests.asp) or [this tutorial](https://realpython.com/python-requests/).

# %%
def get_url_content(url):
    """
    Attempts to get the content within the specified `url` by making a HTTP GET request.
    Return the text content, or None if the response content-type is not HTML/XML.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error(f'Error during requests to {url} : {str(e)}')
        return None
            
def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 and content_type is not None and content_type.find('html') > -1)

def log_error(e):
    """
    A function for printing error logs (extend functionality if needed).
    """
    print(e)

# %%
# from scrapper import get_url_content
raw_html = get_url_content('https://www.cnbc.com/stocks/')
len(raw_html)
# Out:
# 612042

# %%
raw_html
# Out:
# b'<!DOCTYPE html><html lang="en" prefix="og=https://ogp.me/ns#" itemType="https://schema.org/WebPage"><head><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/icomoon.ttf" type="font/ttf" crossorigin="anonymous"/><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/351C86_0_0.woff2" type="font/woff2" crossorigin="anonymous"/><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/351C86_1_0.woff2" type="font/woff2" crossorigin="anonymous"/><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/351C86_2_0.woff2" type="font/woff2" crossorigin="anonymous"/><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/351C86_3_0.woff2" type="font/woff2" crossorigin="anonymous"/><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/351C86_4_0.woff2" type="font/woff2" crossorigin="anonymous"/><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/LyonText-Bold-Web.woff2" type="font/woff2" crossorigin="anonymous"/><link rel="preload" as="font" href="https://static-redesign.cnbcfm.com/dist/LyonText-Regular-Web.woff2" type="font/woff2" crossorigin="anonymous"/><link rel="preload" as="script" href="https://sb.scorecardresearch.com/beacon.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/main-91d00369e2e1a99b8e0e.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/vendors~containers-App-63f59f3b4cf80232d946.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/containers-App~containers-StandAloneComponentApp-1f9351923803ef5e4795.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/containers-App-e0342f0c929999605975.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/vendors~containers-GlobalHeaderContainer~containers-HalfHalfBreakerContainerCNBC~containers-Navigato~5338490a-9c0aa1fae8628b1adcbc.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/vendors~containers-GlobalHeaderContainer~containers-Navigator~containers-QuotePage~containers-SiteMap-398680736bd365018128.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/vendors~containers-Navigator~containers-QuotePage-29248171b9c885d24dc5.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/containers-GlobalHeaderContainer~containers-Navigator~containers-QuotePage~containers-SiteMap-85d3e222bff7ec689871.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/containers-Navigator-7840076aa73c4acd2c2b.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-Ads-TopBanner-fff1d2e411ada559523a.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-PageHeader-a23524a9fb617912cb59.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-TwoColumnImageDense-21ddb998a0ad797a21f9.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-Column-eac9ac4077479682465c.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-MarketNewsTables~components-PcmModule-River~components-shared-Card-a52a5a445fe047ac5612.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-shared-Card-20a68f47601725b0bcd5.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-ThreeUpStack-819ba62fa573484a6c71.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-TrendingNowBreaker-6d4c99573fae97621e07.js"/><link rel="preload" as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-LoadMore-b6118b5a51b02556404d.js"/><title itemProp="name ...

# %% [markdown]
# ___________
# ## 02. Wrangling HTML With BeautifulSoup
# ___________
# After you retrieve the raw HTML material, you will have to parse in order to get only the material that is of relevance to you.
#
# For this, you will be using the `BeautifulSoup` library (that you've installed earlier). The `BeautifulSoup` constructor parses raw HTML strings and produces an object that mirrors the HTML document’s structure, as well as includes numerous methods for selecting, viewing, and/or manipulating the content. For more info, you may to check its [documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/), but generally, the following methods should suffice for the present exercise:
#
# - `find_all(element_tag, ...)`: return all HTML elements from a webpage that have a specified tag and/or some additional attributes.
# In order to get the first one, you may use `find()` instead.
#
# - `get_text()`: extract the text from a HTML element.
#
# You should develop a method `parse_content(raw_html, element_tag, ...)` that:
# 1. Takes a raw `HTML` content as input, passes it to the `BeautifulSoup` constructor.
# 2. Uses `find_all()` method to retrieve a list of the elements of your choice (might also add additional arguments to choose a `class` or etc.).
# 3. Uses the `get_text()` method to retrieve the text content for all the elements retrieved in 2.
#
# The method should return a list of texts retrieved from the elements, and an additional list of attributes related to it (e.g., dates, url links, or anything else that you may find to be useful about).
#
#     You may find dictionary format more suitable in case you decide to store multiple element attributes that do not always exist.
#
# `Note!` - Feel free to use any other `BeautifulSoup` methods if you believe them to fit your approach better.
#
# **`How to start?`**
# Decide upon a webpage and it's field(s) that you want to scrape and
# move your mouse cursor on any of those fields within the webpage. Click the right mouse button, and choose `inspect_element` from a drop down list. Now you will see the content information that will be required for you to access the relevant fields.
#
# Move your code to the `scrapper.py` file, and test your `parse_content()` method as you did in the first exercise.

# %%
soup = BeautifulSoup(raw_html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html itemtype="https://schema.org/WebPage" lang="en" prefix="og=https://ogp.me/ns#"><head><link as="font" crossorigin="anonymous" href="https://static-redesign.cnbcfm.com/dist/icomoon.ttf" rel="preload" type="font/ttf"/><link as="font" crossorigin="anonymous" href="https://static-redesign.cnbcfm.com/dist/351C86_0_0.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://static-redesign.cnbcfm.com/dist/351C86_1_0.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://static-redesign.cnbcfm.com/dist/351C86_2_0.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://static-redesign.cnbcfm.com/dist/351C86_3_0.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://static-redesign.cnbcfm.com/dist/351C86_4_0.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://static-redesign.cnbcfm.com/dist/LyonText-Bold-Web.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://static-redesign.cnbcfm.com/dist/LyonText-Regular-Web.woff2" rel="preload" type="font/woff2"/><link as="script" href="https://sb.scorecardresearch.com/beacon.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/main-91d00369e2e1a99b8e0e.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/vendors~containers-App-63f59f3b4cf80232d946.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/containers-App~containers-StandAloneComponentApp-1f9351923803ef5e4795.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/containers-App-e0342f0c929999605975.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/vendors~containers-GlobalHeaderContainer~containers-HalfHalfBreakerContainerCNBC~containers-Navigato~5338490a-9c0aa1fae8628b1adcbc.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/vendors~containers-GlobalHeaderContainer~containers-Navigator~containers-QuotePage~containers-SiteMap-398680736bd365018128.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/vendors~containers-Navigator~containers-QuotePage-29248171b9c885d24dc5.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/containers-GlobalHeaderContainer~containers-Navigator~containers-QuotePage~containers-SiteMap-85d3e222bff7ec689871.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/containers-Navigator-7840076aa73c4acd2c2b.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-Ads-TopBanner-fff1d2e411ada559523a.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-PageHeader-a23524a9fb617912cb59.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-TwoColumnImageDense-21ddb998a0ad797a21f9.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-Column-eac9ac4077479682465c.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-MarketNewsTables~components-PcmModule-River~components-shared-Card-a52a5a445fe047ac5612.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-shared-Card-20a68f47601725b0bcd5.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-ThreeUpStack-819ba62fa573484a6c71.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-TrendingNowBreaker-6d4c99573fae97621e07.js" rel="preload"/><link as="script" href="https://static-redesign.cnbcfm.com/dist/components-PcmModule-LoadMore-b6118b5a51b02556404d.js" rel="preload"/><title itemprop="name">Stock Market Ne ...
# *{-webkit-box-sizing:border-box;box-sizing:border-box}li,ol,ul{margin:0;padding:0;list-style:none}a{color:#fff;text-decoration:none;cursor:pointer}a:focus,a:hover{color:#ffbc05}button{cursor:pointer;border:none;padding:0;background:none}table{border-collapse:collapse}td,th{text-align:left;padding:8px 15px 8px 0}img{display:block}html{-ms-overflow-style:-ms-autohiding-scrollbar}body{font-family:Proxima Nova,Helvetica,Arial,sans-serif;border:0;padding:0;margin:0;-webkit-font-smoothing:antialiased;-webkit-text-size-adjust:100%}body:after{content:"mobile";display:none}@media (min-width:760px){body:after{content:"tablet"}}@media (min-width:1020px){body:after{content:"small_desktop"}}@media (min-width:1180px){body:after{content:"medium_desktop"}}@media (min-width:1340px){body:after{content:"large_desktop"}}:focus{outline:none}button{font-family:Proxima Nova,Helvetica,Arial,sans-serif;border-radius:0}button::-moz-focus-inner{border:0}.openNav{position:fixed;width:100%}@media (min-width:1020px){.openNav{overflow-y:scroll}}.App-articleBody{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap;padding:0 20px}@media (min-width:760px){.App-articleBody{padding-left:0;padding-right:0}}.group{font-family:Lyon,Helvetica,Arial,sans-serif;font-size:18px;line-height:1.66;margin-bottom:30px}@media (min-width:760px){.group{margin-left:calc(50% + 30px);-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:75%;max-width:75%}}@media (min-width:760px) and (min-width:760px){.group{margin-left:calc(16.66667% + 30px)}}@media (min-width:760px) and (min-width:1020px){.group{margin-left:calc(22.22222% + 30px)}}@media (min-width:760px) and (min-width:1340px){.group{margin-left:calc(16.66667% + 30px)}}@media (min-width:1020px){.group{margin-left:calc(25% + 30px);-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:100%;max-width:100%}}@media (min-width:1020px) and (min-width:760px){.group{margin-left:calc(8.33333% + 30px)}}@media (min-width:1020px) and (min-width:1020px){.group{margin-left:calc(11.11111% + 30px)}}@media (min-width:1020px) and (min-width:1340px){.group{margin-left:calc(8.33333% + 30px)}}@media (min-width:1340px){.group{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:100%;max-width:100%;margin-left:30px}}@media (min-width:1340px) and (min-width:760px){.group{margin-left:14.28571%}}@media (min-width:1340px) and (min-width:1020px){.group{margin-left:14.28571%}}@media (min-width:1340px) and (min-width:1340px){.group{margin-left:14.28571%}}@media (max-width:759px){.hideOnMobile{display:none}}.App-bodyText{color:#2e2e2e;font-family:Lyon,Helvetica,Arial,sans-serif;font-size:18px;line-height:1.66;margin-bottom:30px}@media (min-width:760px){.App-bodyText{margin-left:calc(50% + 30px);-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:75%;max-width:75%}}@media (min-width:760px) and (min-width:760px){.App-bodyText{margin-left:calc(16.66667% + 30px)}}@media (min-width:760px) and (min-width:1020px){.App-bodyText{margin-left:calc(22.22222% + 30px)}}@media (min-width:760px) and (min-width:1340px){.App-bodyText{margin-left:calc(16.66667% + 30px)}}@media (min-width:1020px){.App-bodyText{margin-left:calc(25% + 30px);-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:100%;max-width:100%}}@media (min-width:1020px) and (min-width:760px){.App-bodyText{margin-left:calc(8.33333% + 30px)}}@media (min-width:1020px) and (min-width:1020px){.App-bodyText{margin-left:calc(11.11111% + 30px)}}@media (min-width:1020px) and (min-width:1340px){.App-bodyText{margin-left:calc(8.33333% + 30px)}}@media (min-width:1340px){.App-bodyText{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:100%;max- ...
# .UniversalVideoPlayer-videoContainer{position:absolute;opacity:1;z-index:10}
# @charset "UTF-8";.ErrorHandler-container{background:#ff5053;position:relative;width:100%;height:100%}.SignInMenu-megaMenu{position:fixed;display:block;top:0;left:0;height:100%;width:100%;padding-bottom:45px;background:#fff;z-index:999;color:#071d39;overflow-y:scroll;-webkit-overflow-scrolling:touch;opacity:1}@media (min-width:760px){.SignInMenu-megaMenu{padding-bottom:0}}@media (min-width:1020px){.SignInMenu-megaMenu{overflow:hidden;overflow:auto;height:100%;width:100%}}@media (min-width:1020px){.SignInMenu-megaMenuContainer{margin:0 auto;max-width:100%;display:-webkit-box;display:-ms-flexbox;display:flex;position:relative;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;width:100%}}@media (min-width:1020px) and (min-width:760px){.SignInMenu-megaMenuContainer{max-width:678px}}@media (min-width:1020px) and (min-width:1020px){.SignInMenu-megaMenuContainer{max-width:960px}}@media (min-width:1020px) and (min-width:1340px){.SignInMenu-megaMenuContainer{max-width:1290px}}.SignInMenu-searchToggle{display:block;padding:20px;border-bottom:1px solid #9b9b9b;background-color:#fff}@media (min-width:1020px){.SignInMenu-searchToggle{background-color:transparent;border-bottom:none;padding:27px 40px;position:absolute;right:0;z-index:1}}.SignInMenu-topBar{position:fixed;bottom:0;left:0;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;min-height:45px;height:45px;max-height:45px;padding:0 45px 0 20px;background-color:#005594;z-index:5}@media (min-width:760px){.SignInMenu-topBar{position:relative;-webkit-box-pack:start;-ms-flex-pack:start;justify-content:flex-start}}@media (min-width:1020px){.SignInMenu-topBar{position:absolute;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-align:center;-ms-flex-align:center;align-items:center;top:0;left:0;min-height:92px;height:102px;max-height:102px;padding:0 0 0 8px;background-color:transparent;width:50%}}@media (min-width:1340px){.SignInMenu-topBar{height:102px;max-height:102px}}.SignInMenu-close{-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2;color:#fff;background:none;font-size:17px}.SignInMenu-close span:before{display:block}.SignInMenu-close:focus,.SignInMenu-close:hover{color:#fcb700}@media (min-width:760px){.SignInMenu-close{-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1}}@media (min-width:1020px){.SignInMenu-close{color:#005594;font-size:15px}}.SignInMenu-logo{-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1;-webkit-box-flex:1;-ms-flex:1;flex:1;min-width:35px;max-width:35px}@media (min-width:760px){.SignInMenu-logo{-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2;margin-left:30px}}@media (min-width:1020px){.SignInMenu-logo{min-width:120px;max-width:120px}}.SignInMenu-logo img{width:100%}@media (min-width:1020px){.SignInMenu-logoSmall{display:none}}.SignInMenu-logoLarge{display:none}@media (min-width:1020px){.SignInMenu-logoLarge{display:block}}.SignInMenu-search{font-weight:600;margin-right:30px;color:#fff;font-size:14px;letter-spacing:1px}@media (min-width:1340px){.SignInMenu-search{margin-right:75px}}.SignInMenu-account{display:none}@media (min-width:1020px){.SignInMenu-account{display:block}}@media (min-width:1020px){.SignInMenu-makeit{border-left:1px solid rgba(102,153,190,.5);padding-left:15px}}.SignInMenu-accountLinks{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;text-transform:uppercase}.SignInMenu-accountLinks li{height:70px;line-height:70px;padding:0 20px;text-align:center}.SignInMenu-accountLinks a{font-weight:600;color:#071d39;font-size:14px;letter-spaci ...
# .Footer-container{z-index:99;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap;background-color:#071d39;color:#fff;text-align:left;position:relative;padding:0 20px 63px;width:100%;overflow:hidden}@media (min-width:760px){.Footer-container{padding-left:0;padding-right:0}}.Footer-container h4{color:#fff!important}@media (min-width:760px){.Footer-container{padding-bottom:40px}}@media (min-width:1020px){.Footer-container{padding:30px 0}}@media (-ms-high-contrast:active),only screen and (-ms-high-contrast:none){.Footer-container{-ms-flex-flow:column wrap;-webkit-box-align:center;-ms-flex-align:center;align-items:center}}.Footer-gridContainer{margin:0 auto;max-width:100%}@media (min-width:760px){.Footer-gridContainer{max-width:678px}}@media (min-width:1020px){.Footer-gridContainer{max-width:960px}}@media (min-width:1340px){.Footer-gridContainer{max-width:1290px}}.Footer-wrapper{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:calc((100% - 90px)/4*4 + 90px);max-width:calc((100% - 90px)/4*4 + 90px);position:relative}@media (min-width:760px){.Footer-wrapper{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:calc((100% - 330px)/12*12 + 330px);max-width:calc((100% - 330px)/12*12 + 330px)}}@media (min-width:1020px){.Footer-wrapper{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:calc((100% - 240px)/9*9 + 240px);max-width:calc((100% - 240px)/9*9 + 240px)}}@media (min-width:1340px){.Footer-wrapper{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:calc((100% - 330px)/12*12 + 330px);max-width:calc((100% - 330px)/12*12 + 330px)}}.Footer-header{width:100%;border-bottom:1px solid hsla(0,0%,100%,.5);display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px}.Footer-header img{width:130px}@media (min-width:760px){.Footer-header{padding-left:calc((100% - 678px)/2);padding-right:calc((100% - 678px)/2)}}@media (min-width:1020px){.Footer-header{max-width:100%;height:45px;-webkit-box-align:end;-ms-flex-align:end;align-items:flex-end;padding:0 0 15px;margin:0}}@media (min-width:1340px){.Footer-content{display:-webkit-box;display:-ms-flexbox;display:flex;-ms-flex-wrap:wrap;flex-wrap:wrap}}.Footer-menu{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap;padding:0;margin:30px 0 10px}@media (min-width:1020px){.Footer-menu{margin-top:20px}}@media (min-width:1340px){.Footer-menu{display:inline-block;width:50%}}.Footer-menu li{font-weight:500;-webkit-box-flex:calc(50% - 10px);-ms-flex:calc(50% - 10px);flex:calc(50% - 10px);font-size:16px;margin-bottom:10px}.Footer-menu li:nth-child(odd){margin-right:20px}@media (min-width:760px){.Footer-menu li{-webkit-box-flex:33%;-ms-flex:33%;flex:33%;max-width:33%}.Footer-menu li:nth-child(odd){margin-right:0}}@media (min-width:1020px){.Footer-menu li{font-size:14px;line-height:26px}}@media (min-width:1340px){.Footer-menu li{display:inline-block;width:33%}}.Footer-share{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;margin:30px 0 40px;padding:0}@media (min-width:760px){.Footer-share{position:absolute;line-height:65px;top:0;right:0;margin-top:0}}@media (min-width:1020px){.Footer-share{line-height:45px;height:45px}}.Footer-share li{font-size:22px;margin:0 10px}@media (min-width:760px){.Footer-info{display:-webkit-box;display:-ms-flexbox;d ...
# @media (min-width:360px) and (max-width:759px){.Layout-layout{width:100%}}@media (min-width:760px){.Layout-layout{display:-webkit-box;display:-ms-flexbox;display:flex;-ms-flex-wrap:wrap;flex-wrap:wrap}}
# .NativeThreeUp-container{display:-webkit-box;display:-ms-flexbox;display:flex}.NativeThreeUp-container,.NativeThreeUpStackv2-container{-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-ms-flex-item-align:center;align-self:center;margin:0}.NativeThreeUpStackv2-container{display:-webkit-box;display:-ms-flexbox;display:flex;display:none}.NativeUltraDense-container{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-ms-flex-item-align:center;align-self:center;margin:0}
# @media (min-width:360px) and (max-width:759px){.Layout-layout{width:100%}}@media (min-width:760px){.Layout-layout{display:-webkit-box;display:-ms-flexbox;display:flex;-ms-flex-wrap:wrap;flex-wrap:wrap}}.ThreeUpStack-container{margin:0 0 20px}@media (min-width:1020px){.ThreeUpStack-container{margin-bottom:16px}}@media (min-width:1340px){.ThreeUpStack-container{margin-bottom:15px}}@media (min-width:760px) and (max-width:1019px){.ThreeUpStack-container{width:678px;margin:0 auto;padding-bottom:20px}}
# .BrandPageWrapper-contentWrapper{margin-top:45px;position:relative;overflow:visible}@media (min-width:1020px){.BrandPageWrapper-contentWrapper{overflow:visible}}.BrandPageWrapper-contentWrapper.BrandPageWrapper-xfinity{margin-top:89px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-countDownClock{margin-top:112px}@media (min-width:760px){.BrandPageWrapper-contentWrapper{margin-top:70px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-xfinity{margin-top:114px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-countDownClock{margin-top:112px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-countDownClock.BrandPageWrapper-xfinity{margin-top:156px}}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert{margin-top:85px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-xfinity{margin-top:129px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-liveAlert{margin-top:125px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-countDownClock{margin-top:192px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-xfinity.BrandPageWrapper-liveAlert{margin-top:169px}@media (min-width:760px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert{margin-top:110px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-xfinity{margin-top:154px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-liveAlert{margin-top:150px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-countDownClock{margin-top:152px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-countDownClock.BrandPageWrapper-xfinity{margin-top:196px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert.BrandPageWrapper-xfinity.BrandPageWrapper-liveAlert{margin-top:194px}}.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert{margin-top:85px}@media (min-width:360px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-xfinity{margin-top:128px}}@media (min-width:760px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-xfinity{margin-top:154px}}@media (min-width:1020px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-xfinity{margin-top:154px}}@media (min-width:1340px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-xfinity{margin-top:154px}}@media (min-width:360px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-newsAlert{margin-top:125px}}@media (min-width:760px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-newsAlert{margin-top:150px}}@media (min-width:1020px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-newsAlert{margin-top:150px}}@media (min-width:1340px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-newsAlert{margin-top:150px}}.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-newsAlert.BrandPageWrapper-countDownClock{margin-top:192px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-newsAlert.BrandPageWrapper-countDownClock.BrandPageWrapper-xfinity{margin-top:236px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-countDownClock{margin-top:152px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert.BrandPageWrapper-countDownClock.BrandPageWrapper-xfinity{margin-top:196px}@media (min-width:760px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert{margin-top:110px}}@media (min-width:1020px){.BrandPageWrapper-contentWrapper.BrandPageWrapper-liveAlert .Ad-adWrapperSticky,.BrandPageWrapper-contentWrapper.BrandPageWrapper-newsAlert .Ad-adWrapperSticky{top:120px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-xfinity .Ad-adWrapperSticky{top:124px}.BrandPageWrapper-contentWrapper.BrandPageWrapper-countDownClock .Ad-adWrapperSticky{top:122px}.BrandPag ...
# .nav-menu-navMenu{background-color:#005594;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 20px;left:0;overflow:hidden;height:54px;z-index:99}@media (min-width:760px){.nav-menu-navMenu{padding:0 20px}}@media (min-width:1020px){.nav-menu-navMenu{background-color:transparent;height:35px;padding:0 15px 0 30px}}.nav-menu-navMenu{position:fixed;bottom:0;width:100%;-webkit-transition:background-color .25s;transition:background-color .25s;padding-left:8px}@media (max-width:1019px){.nav-menu-navMenu{padding-left:28px}}@media (min-width:760px){.nav-menu-navMenu{-webkit-transition:top .25s,height .25s,width .25s;transition:top .25s,height .25s,width .25s;top:31px;overflow:visible;position:absolute;height:36px;background-color:transparent}}@media (min-width:1020px){.nav-menu-navMenu{top:31px;position:absolute;width:70%;z-index:999}.nav-menu-navMenu.nav-menu-navMenuSticky{padding-bottom:19px}}@media (min-width:1340px){.nav-menu-navMenu{top:31px}}@media only screen and (device-width:375px) and (device-height:812px) and (-webkit-device-pixel-ratio:3){.nav-menu-navMenu{overflow:visible;margin-bottom:0}.nav-menu-navMenu:after{-webkit-transition:background-color .25s;transition:background-color .25s;background:#005594;content:"";width:100%;height:21px;position:absolute;bottom:-20px;left:0}}@media (min-width:760px) and (max-width:1019px){.nav-menu-navMenu{z-index:0}}@media (min-width:760px){.nav-menu-navMenuArticle{pointer-events:auto}}.nav-menu-navMenuSticky{z-index:1000;background:#005594}@media (min-width:760px){.nav-menu-navMenuSticky{height:45px;top:0}}@media (min-width:1020px){.nav-menu-navMenuSticky{height:45px;top:0}}.nav-menu-navMenuSticky.nav-menu-withOpenSearch{z-index:1000}.nav-menu-navMenuArticleSticky{color:#000;background:#fff}@media (min-width:760px){.nav-menu-navMenuArticleSticky{background:transparent;z-index:999;width:100%}}@media only screen and (device-width:375px) and (device-height:812px) and (-webkit-device-pixel-ratio:3){.nav-menu-navMenuArticleSticky:after{background:#fff}}.nav-menu-navMenuArticleSticky .nav-menu-logoStickyContainer{margin-right:5%}@media (min-width:1020px){.nav-menu-navMenuArticleSticky .nav-menu-logoStickyContainer{margin-right:0}}.nav-menu-button{background-color:transparent;border:0;color:#fff;font-size:18px;padding:0;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2}.nav-menu-button .icon-cnbctv{position:relative;top:4px;font-size:26px;margin-bottom:-3px}.nav-menu-button .icon-news{position:relative;top:4px;font-size:23px}.nav-menu-button .icon-markets,.nav-menu-button .icon-watchlist{position:relative;top:7px;font-size:18px;padding-bottom:5px}.nav-menu-button:focus .nav-menu-buttonText{color:#fff}.nav-menu-button+.nav-menu-subLinks{display:none;position:absolute;font-size:12px;background:hsla(0,0%,100%,.97);margin:0 15px;padding:0;-webkit-transform:translate(.7px,-1px);transform:translate(.7px,-1px);-webkit-transform-origin:top left;transform-origin:top left}.nav-menu-button+.nav-menu-subLinks li{border-bottom:2px solid #f3f5f7;position:relative;z-index:600;padding:0 20px}.nav-menu-button+.nav-menu-subLinks li:first-child{padding:5px 20px 0}.nav-menu-button+.nav-menu-subLinks li:last-child{padding:0 20px 5px;border-bottom:none}.nav-menu-button+.nav-menu-subLinks li:hover{background-color:#f3f5f7}.nav-menu-button+.nav-menu-subLinks li:hover .nav-menu-subLink{opacity:0}.nav-menu-button+.nav-menu-subLinks li:hover:first-child:before{top:9px}.nav-menu-button+.nav-menu-subLinks li:hover:before{position:absolute;font-weight:700;content:attr(data-text);top:4px;color:#005594;pointer-events:none}.nav-men ...
# .SearchToggle-button{position:absolute;top:0;right:5px;height:37px;width:45px;color:#fff;z-index:0;border-radius:0;padding:6px;margin-top:3px}.SearchToggle-button.SearchToggle-closeButtonText{font-size:16px;font-weight:600;margin-left:-50px;width:auto;right:14px}.SearchToggle-button .icon-search{display:block}.SearchToggle-button .icon-search:before{font-size:24px;-webkit-transition:font-size .25s;transition:font-size .25s}.SearchToggle-button .icon-close:before{font-size:18px}.SearchToggle-button span{display:none;font-weight:700;font-size:12px;letter-spacing:.85px;text-transform:uppercase;opacity:1;-webkit-transition:opacity .25s;transition:opacity .25s;left:10px;top:10px;position:absolute}.SearchToggle-button.SearchToggle-searchOpen{background:inherit}@media (min-width:760px){.SearchToggle-button{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:end;-ms-flex-pack:end;justify-content:flex-end;-webkit-box-align:center;-ms-flex-align:center;align-items:center;right:3px;width:155px;height:37px;padding:0 20px 0 15px;background:#336aa0;margin-top:10px;margin-right:17px}.SearchToggle-button span{display:block;margin-right:32px;left:12px}.SearchToggle-button span.SearchToggle-megaMenuSearchToggler{left:30px;top:10px}.SearchToggle-button .icon-search{position:absolute;height:20px;right:10px;top:0;bottom:0;margin:auto}.SearchToggle-button .icon-search:before{font-size:20px}.SearchToggle-button:before{content:"";background-color:rgba(102,153,190,.5);position:absolute;left:0;top:50%;-webkit-transform:translateY(-50%);transform:translateY(-50%);height:calc(100% - 30px)}}@media (min-width:1020px){.SearchToggle-button{position:absolute;top:auto;bottom:auto;right:0;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-left:20px;padding-right:0;width:155px;-webkit-transition:height .25s,-webkit-transform .25s;transition:height .25s,-webkit-transform .25s;transition:transform .25s,height .25s;transition:transform .25s,height .25s,-webkit-transform .25s;height:37px;margin-top:10px;background:#336aa0;margin-right:0}.SearchToggle-button span{left:10px;top:10px}.SearchToggle-button span.SearchToggle-megaMenuSearchToggler{left:10px}.SearchToggle-button .icon-search{right:10px;bottom:0}}.SearchToggle-mega-menu .SearchToggle-button{position:relative;width:auto}@media (min-width:1340px){.SearchToggle-mega-menu .SearchToggle-button{padding:0;margin:0 75px}}.SearchToggle-articleButton.SearchToggle-buttonSticky{color:#005594;width:39px;z-index:999;background:none;border-left:1px solid #e8e8e8;padding-left:43px}@media (min-width:760px){.SearchToggle-articleButton.SearchToggle-buttonSticky{margin-right:10px;padding-left:22px}}@media (min-width:1020px){.SearchToggle-articleButton.SearchToggle-buttonSticky{display:block;line-height:1px;margin-right:0;padding-left:43px}.SearchToggle-articleButton.SearchToggle-buttonSticky:before{content:"";width:1px;height:30px;display:block;background:none;position:absolute;left:0;bottom:0}}.SearchToggle-buttonSticky{-webkit-transform:translateY(-100%);transform:translateY(-100%);z-index:1000}@media (min-width:760px){.SearchToggle-buttonSticky{-webkit-transform:translateY(0);transform:translateY(0);height:26px;width:75px;-webkit-transition:width 0s .25s;transition:width 0s .25s;background:#005594}.SearchToggle-buttonSticky:before{display:none}.SearchToggle-buttonSticky span{opacity:0;-webkit-transition:opacity .25s;transition:opacity .25s}.SearchToggle-buttonSticky .icon-search{height:26px}.SearchToggle-buttonSticky .icon-search:before{font-size:26px}}@media (min-width:1020px){.SearchToggle-buttonSticky .icon-search,.SearchToggle-buttonSticky .icon-search:before{font-size:26px}}@media (-ms-high-contrast:none),screen and (-ms-high-contrast:active){.SearchToggle-buttonSticky{height:35px}}.SearchToggle-megaMenuButton{position:relative;display:-webkit-box;display:-ms-flexbox;display:flex; ...
# .PageBuilder-containerFluidWidths{margin:0 auto;width:100%}@media (min-width:1020px){.PageBuilder-containerFluidWidths{max-width:960px}}@media (min-width:1340px){.PageBuilder-containerFluidWidths{max-width:1290px}}.PageBuilder-containerWidth100{width:100%}.PageBuilder-page{display:block;overflow:visible;margin-bottom:25px}@media (min-width:760px){.PageBuilder-page{margin-bottom:28px}}.PageBuilder-pageGrid{overflow:visible;margin-right:auto;margin-left:auto;max-width:1290px;width:100%}.PageBuilder-pageWrapper{margin:0 auto;max-width:100%}@media (min-width:760px){.PageBuilder-pageWrapper{max-width:678px}}@media (min-width:1020px){.PageBuilder-pageWrapper{max-width:960px}}@media (min-width:1340px){.PageBuilder-pageWrapper{max-width:1290px}}@media (min-width:760px){.PageBuilder-pageWrapper{max-width:100%!important}}.PageBuilder-pageRow{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap;padding:0 20px}@media (min-width:760px){.PageBuilder-pageRow{padding-left:0;padding-right:0}}@media (min-width:1020px){.PageBuilder-pageRow{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap;padding:0 20px}}@media (min-width:1020px) and (min-width:760px){.PageBuilder-pageRow{padding-left:0;padding-right:0}}@media (max-width:1019px){.PageBuilder-pageRow{padding:0;margin:0}}@media (min-width:360px) and (max-width:759px){.PageBuilder-pageRow.PageBuilder-containerFluidWidths{padding:0 21px}}@media (min-width:760px) and (max-width:1019px){.PageBuilder-pageRow.PageBuilder-containerFluidWidths{padding:0 45px}}.PageBuilder-pageRowFlex{display:-webkit-box;display:-ms-flexbox;display:flex}.PageBuilder-rowUnderAd{margin-top:-29px}@media (min-width:1020px){.PageBuilder-rowUnderAd{margin-top:-50px}}@media (min-width:1340px){.PageBuilder-rowUnderAd{margin-top:-44px}}.PageBuilder-rowWithBackground{position:relative;background:#cfd8e2}.PageBuilder-rowWithBackground:after,.PageBuilder-rowWithBackground:before{content:"";width:25vw;height:100%;display:block;position:absolute;background:#cfd8e2}.PageBuilder-rowWithBackground:before{right:100%;top:0}.PageBuilder-rowWithBackground:after{left:100%;top:0}.PageBuilder-flipRowOrder .PageBuilder-col:first-child{-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2}@media (min-width:1020px){.PageBuilder-flipRowOrder .PageBuilder-col:first-child{-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1}}.PageBuilder-flipRowOrder .PageBuilder-col:last-child{-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1}@media (min-width:1020px){.PageBuilder-flipRowOrder .PageBuilder-col:last-child{-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2}}.PageBuilder-col{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:calc(100% - 30px);max-width:calc(100% - 30px);margin-right:30px;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column}@media (min-width:760px){.PageBuilder-col{min-width:calc(33.33333% - 30px);max-width:calc(33.33333% - 30px)}}@media (min-width:1020px){.PageBuilder-col{min-width:calc(44.44444% - 30px);max-width:calc(44.44444% - 30px)}}@media screen and (min-width:1020px) and (-ms-high-contrast:none){.PageBuilder-col{min-width:100%;max-width:100%}}@media (min-width:1340px){.PageBuilder-col{min-width:calc(33.33333% - 30px);max-width:calc(33.33333% - 30px)}}.PageBuilder-col:last-child{margin-right:0}@media (min-width:360px) and (max-width:759px){.PageBuilder-col{max-width:100%!important;min-width:100%!important;margin-left:auto!important;margin-right:auto!important}}@media (min-width:760px) and (max-width:1019px){.PageBuilder-col{max-width:100%!important;min-width:100%!important;margin-left:auto!important;margin-right:a ...
# .TopBanner-container{text-align:center;overflow:hidden;width:100%}@media (min-width:760px){.TopBanner-container{min-width:728px;margin:0 auto;padding:15px 0}}@media (min-width:1020px){.TopBanner-container{margin-right:auto;margin-left:auto}}
# .PageHeader-container{text-transform:uppercase;color:#002f6c;margin:0 0 20px}.PageHeader-container .PageHeader-main .PageHeader-eyebrowContainer{margin:13px 0 4px;line-height:14px}@media (min-width:760px){.PageHeader-container .PageHeader-main .PageHeader-eyebrowContainer{margin:0 0 4px}}.PageHeader-container .PageHeader-main .PageHeader-eyebrowContainer .PageHeader-eyebrow{color:#002f6c;font-weight:700;font-size:12px;letter-spacing:.08em;line-height:100%;margin:0 auto}@media (min-width:1020px){.PageHeader-container .PageHeader-main .PageHeader-eyebrowContainer .PageHeader-eyebrow{font-size:14px}}.PageHeader-container .PageHeader-main .PageHeader-eyebrowContainer .PageHeader-eyebrow:hover{color:#ffbc05}.PageHeader-container .PageHeader-main .PageHeader-proPadding{margin-top:15px}@media (min-width:1020px){.PageHeader-container .PageHeader-main .PageHeader-proPadding{margin-top:30px}}.PageHeader-container .PageHeader-main .PageHeader-title{font-weight:800;line-height:100%;font-size:22px;margin:13px 0}@media (min-width:760px){.PageHeader-container .PageHeader-main .PageHeader-title{margin:0 0 13px}}@media (min-width:1020px){.PageHeader-container .PageHeader-main .PageHeader-title{font-size:32px;margin:0 0 15px}}@media (prefers-color-scheme:dark){.webview .PageHeader-container,.webview .PageHeader-container .PageHeader-main .PageHeader-eyebrowContainer .PageHeader-eyebrow{color:#2077b6}}.PageHeader-notSpecialReport .PageHeader-main{text-align:center;padding:0 0 5px}.PageHeader-background{background-size:cover;background-position:50% 50%;border-bottom:6px solid;height:86px;position:relative}@media (min-width:760px){.PageHeader-background{height:106px}}@media (min-width:1020px){.PageHeader-background{height:126px}}.PageHeader-logoAndSponsorWrapper{width:100%;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:start;-ms-flex-align:start;align-items:flex-start;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;z-index:1;margin:-45px auto 0}@media (min-width:1020px){.PageHeader-logoAndSponsorWrapper{max-width:960px}}@media (min-width:1340px){.PageHeader-logoAndSponsorWrapper{max-width:1290px}}@media (min-width:360px) and (max-width:759px){.PageHeader-logoAndSponsorWrapper{padding:0 0 0 21px}}@media (min-width:760px) and (max-width:1019px){.PageHeader-logoAndSponsorWrapper{padding:0 45px}}@media (min-width:760px){.PageHeader-logoAndSponsorWrapper{margin-top:-80px}}@media (min-width:1020px){.PageHeader-logoAndSponsorWrapper{margin-top:-90px}}.PageHeader-logoAndSponsorWrapper.PageHeader-textWrapper{margin-top:-30px}@media (min-width:760px){.PageHeader-logoAndSponsorWrapper.PageHeader-textWrapper{margin-top:-50px}}@media (min-width:760px){.PageHeader-logoAndSponsorWrapper.PageHeader-textWrapper .PageHeader-sponsorLogo{margin-top:-5px}}.PageHeader-logoAndSponsorWrapper .PageHeader-logoOrTitle{position:relative;font-weight:800;background-color:#fff;line-height:1.05;text-transform:uppercase;max-width:173px;padding:15px 13px 0 0}@media (min-width:760px){.PageHeader-logoAndSponsorWrapper .PageHeader-logoOrTitle{max-width:330px;padding:30px 30px 0 0}}.PageHeader-logoAndSponsorWrapper .PageHeader-logoOrTitle:before{content:"";background-color:#fff;position:absolute;top:0;left:0;height:100%;-webkit-transform:translateX(-100%);transform:translateX(-100%);width:100vw}.PageHeader-logoAndSponsorWrapper .PageHeader-logoOrTitle .PageHeader-title{margin:0;font-size:16px;color:#002f6c}@media (min-width:760px){.PageHeader-logoAndSponsorWrapper .PageHeader-logoOrTitle .PageHeader-title{font-size:28px}}@media (min-width:360px){.PageHeader-logoAndSponsorWrapper .PageHeader-logoOrTitle .PageHeader-logoImg{width:90px;height:45px}}@media (min-width:760px){.PageHeader-logoAndSponsorWrapper .PageHeader-logoOrTitle .PageHeader-logoImg{width:170px;height:85px}}@media (min-width:1020px){.PageHeader-logoAndSponsorWrapper .PageHeader-logoOrTitle .PageHeader-logoImg{width:190px;height:95px}}@media (min-width:1340px){.PageHead ...
# .TwoColumnImageDense-containerFluidWidths{margin:0 auto;width:100%}@media (min-width:1020px){.TwoColumnImageDense-containerFluidWidths{max-width:960px}}@media (min-width:1340px){.TwoColumnImageDense-containerFluidWidths{max-width:1290px}}.TwoColumnImageDense-containerWidth100{width:100%}.TwoColumnImageDense-page{display:block;overflow:visible;margin-bottom:25px}@media (min-width:760px){.TwoColumnImageDense-page{margin-bottom:28px}}.TwoColumnImageDense-pageGrid{overflow:visible;margin-right:auto;margin-left:auto;max-width:1290px;width:100%}.TwoColumnImageDense-pageWrapper{margin:0 auto;max-width:100%}@media (min-width:760px){.TwoColumnImageDense-pageWrapper{max-width:678px}}@media (min-width:1020px){.TwoColumnImageDense-pageWrapper{max-width:960px}}@media (min-width:1340px){.TwoColumnImageDense-pageWrapper{max-width:1290px}}@media (min-width:760px){.TwoColumnImageDense-pageWrapper{max-width:100%!important}}.TwoColumnImageDense-pageRow{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap;padding:0 20px}@media (min-width:760px){.TwoColumnImageDense-pageRow{padding-left:0;padding-right:0}}@media (min-width:1020px){.TwoColumnImageDense-pageRow{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap;padding:0 20px}}@media (min-width:1020px) and (min-width:760px){.TwoColumnImageDense-pageRow{padding-left:0;padding-right:0}}@media (max-width:1019px){.TwoColumnImageDense-pageRow{padding:0;margin:0}}@media (min-width:360px) and (max-width:759px){.TwoColumnImageDense-pageRow.TwoColumnImageDense-containerFluidWidths{padding:0 21px}}@media (min-width:760px) and (max-width:1019px){.TwoColumnImageDense-pageRow.TwoColumnImageDense-containerFluidWidths{padding:0 45px}}.TwoColumnImageDense-pageRowFlex{display:-webkit-box;display:-ms-flexbox;display:flex}.TwoColumnImageDense-rowUnderAd{margin-top:-29px}@media (min-width:1020px){.TwoColumnImageDense-rowUnderAd{margin-top:-50px}}@media (min-width:1340px){.TwoColumnImageDense-rowUnderAd{margin-top:-44px}}.TwoColumnImageDense-rowWithBackground{position:relative;background:#cfd8e2}.TwoColumnImageDense-rowWithBackground:after,.TwoColumnImageDense-rowWithBackground:before{content:"";width:25vw;height:100%;display:block;position:absolute;background:#cfd8e2}.TwoColumnImageDense-rowWithBackground:before{right:100%;top:0}.TwoColumnImageDense-rowWithBackground:after{left:100%;top:0}.TwoColumnImageDense-flipRowOrder .TwoColumnImageDense-col:first-child{-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2}@media (min-width:1020px){.TwoColumnImageDense-flipRowOrder .TwoColumnImageDense-col:first-child{-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1}}.TwoColumnImageDense-flipRowOrder .TwoColumnImageDense-col:last-child{-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1}@media (min-width:1020px){.TwoColumnImageDense-flipRowOrder .TwoColumnImageDense-col:last-child{-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2}}.TwoColumnImageDense-col{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:calc(100% - 30px);max-width:calc(100% - 30px);margin-right:30px;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column}@media (min-width:760px){.TwoColumnImageDense-col{min-width:calc(33.33333% - 30px);max-width:calc(33.33333% - 30px)}}@media (min-width:1020px){.TwoColumnImageDense-col{min-width:calc(44.44444% - 30px);max-width:calc(44.44444% - 30px)}}@media screen and (min-width:1020px) and (-ms-high-contrast:none){.TwoColumnImageDense-col{min-width:100%;max-width:100%}}@media (min-width:1340px){.TwoColumnImageDense-col{min-width:calc(33.33333% - 30px);max-width:calc(33.33333% - 30px)}}.TwoColumnImageDense-col: ...
# .SectionWrapper-container{position:relative;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;width:100%;padding-top:5px}.SectionWrapper-container .SectionHeader-container{display:none}.SectionWrapper-container .MustWatchVideo-container{max-width:none;-webkit-box-flex:1;-ms-flex-positive:1;flex-grow:1;margin-right:-30px}@media (min-width:760px){.SectionWrapper-container{-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:wrap;flex-wrap:wrap}}@media (min-width:1020px){.SectionWrapper-twoThirds{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:calc(150% - 30px);max-width:calc(150% - 30px)}}@media (min-width:1020px) and (min-width:760px){.SectionWrapper-twoThirds{min-width:calc(50% - 30px);max-width:calc(50% - 30px)}}@media (min-width:1020px) and (min-width:1020px){.SectionWrapper-twoThirds{min-width:calc(66.66667% - 30px);max-width:calc(66.66667% - 30px)}}@media screen and (min-width:1020px) and (min-width:1020px) and (-ms-high-contrast:none){.SectionWrapper-twoThirds{min-width:100%;max-width:100%}}@media (min-width:1020px) and (min-width:1340px){.SectionWrapper-twoThirds{min-width:calc(50% - 30px);max-width:calc(50% - 30px)}}@media (min-width:1340px){.SectionWrapper-twoThirds{-webkit-box-flex:0;-ms-flex-positive:0;flex-grow:0;-ms-flex-negative:0;flex-shrink:0;min-width:calc(225% - 30px);max-width:calc(225% - 30px)}}@media (min-width:1340px) and (min-width:760px){.SectionWrapper-twoThirds{min-width:calc(75% - 30px);max-width:calc(75% - 30px)}}@media (min-width:1340px) and (min-width:1020px){.SectionWrapper-twoThirds{min-width:calc(100% - 30px);max-width:calc(100% - 30px)}}@media screen and (min-width:1340px) and (min-width:1020px) and (-ms-high-contrast:none){.SectionWrapper-twoThirds{min-width:100%;max-width:100%}}@media (min-width:1340px) and (min-width:1340px){.SectionWrapper-twoThirds{min-width:calc(75% - 30px);max-width:calc(75% - 30px)}}.SectionWrapper-header{position:relative;-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1;border-top:1px solid #747474}@media (min-width:760px){.SectionWrapper-header{-webkit-box-flex:1;-ms-flex-positive:1;flex-grow:1}}.SectionWrapper-decoration{display:block;position:absolute;top:-6px;left:0;height:6px;width:80px;background-color:#fcb700}@media (min-width:760px){.SectionWrapper-decoration{width:110px}}.SectionWrapper-title{font-weight:800;margin:15px 0;text-transform:uppercase;font-size:30px;line-height:1;letter-spacing:.5px;color:#002f6c}.SectionWrapper-title a{color:inherit}.SectionWrapper-title a:focus,.SectionWrapper-title a:hover{color:#2077b6}@media (min-width:1020px){.SectionWrapper-title{margin-top:20px;font-size:32px}}.SectionWrapper-titleImage{height:30px;width:auto;max-width:100%;margin:15px 0}@media (min-width:1020px){.SectionWrapper-titleImage{margin-top:20px;height:40px}}.SectionWrapper-sponsorIcon{display:none}@media (min-width:1020px){.SectionWrapper-sponsorIcon{display:block;position:absolute;right:0;top:0;bottom:0;height:31px;margin:auto}}.SectionWrapper-link{font-weight:600;-webkit-box-ordinal-group:4;-ms-flex-order:3;order:3;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;flex-direction:center;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;width:100%;height:40px;border:1px solid #002f6c;color:#002f6c;font-size:12px;letter-spacing:1px;line-height:12px;text-transform:uppercase;text-align:center;-webkit-transition:all .15s ease-out;transition:all .15s ease-out}.SectionWrapper-link:focus,.SectionWrapper-link:hover{color:#002f6c;background-color:#fcb700;border-color:#fcb700}@media (min-width:760px){.SectionWrapper-link{-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2;max-width:168px;min-width:168px;margin-left:30px}}@media (mi ...
# ...
# .ModuleHeader-container{width:100%;margin:5px 0 32px;padding:0;position:relative;border-top:1px solid #747474}.ModuleHeader-container:before{content:"";position:absolute;width:48px;height:6px;background:#2077b6;top:-6px;left:0;z-index:2}@media (min-width:1340px){.ModuleHeader-container:before{width:110px}}.ModuleHeader-container h2{padding:0;font-size:20px;font-weight:800;text-transform:uppercase;display:inline-block;width:100%;margin:15px 0 0;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;color:#002f6c;letter-spacing:.33px;line-height:1}@media (min-width:760px){.ModuleHeader-container h2{font-size:30px;margin:18px 0 0}}@media (min-width:1340px){.ModuleHeader-container h2{font-size:32px}}.ModuleHeader-title a{color:#002f6c}
# .LoadMore-container{width:100%}
# .LoadMoreButton-loadMore{font-weight:600;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;height:40px;width:100%;padding:0 20px;border:1px solid #002f6c;background-color:#fff;color:#002f6c;font-size:12px;letter-spacing:1px;text-align:center;text-transform:uppercase;-webkit-transition:all .15s linear;transition:all .15s linear;margin:0 auto;display:table}.LoadMoreButton-loadMore>span{display:block;line-height:12px}.LoadMoreButton-loadMore [class*=" icon-"],.LoadMoreButton-loadMore [class^=icon-]{position:relative;margin-left:5px;height:12px}.LoadMoreButton-loadMore [class*=" icon-"]:before,.LoadMoreButton-loadMore [class^=icon-]:before{line-height:12px}.LoadMoreButton-loadMore:focus,.LoadMoreButton-loadMore:hover{border-color:#002f6c;background-color:#002f6c;color:#fff}.LoadMoreButton-loadMore[class*=touchButton]:hover{border-color:#002f6c;background-color:#fff;color:#002f6c}@media (hover:hover){.LoadMoreButton-loadMore[class*=touchButton]:hover{border-color:#002f6c;background-color:#002f6c;color:#fff}}@media (min-width:760px){.LoadMoreButton-loadMore{width:auto;padding:0 30px}}.LoadMoreButton-loadMore:focus{border-color:#002f6c;background-color:#fff;color:#002f6c}.LoadMoreButton-loadMore:hover{border-color:#002f6c;background-color:#002f6c;color:#fff}.LoadMoreButton-loadMore div{text-align:center;vertical-align:middle;display:table-cell}</style></head><body><div><!-- Comscore Identifier: comscorekw=Markets|stocks --></div><div id="root"><div><div class="AuthModal-surfPopupBackground" style="display:none"><div class="AuthModal-surfContainer" id="surfContainer"><div class="AuthModal-logoContainer"><div class="AuthModal-logo"><img alt="CNBC logo" src="data:image/png;base64,..."/></div><a class="AuthModal-surfCloseBtn" role="button" tabindex="0">×</a></div><div class="AuthModal-SignInSignUp"><ul class="AuthModal-tab"><li><a role="button" tabindex="0">LOG IN</a></li><li><a role="button" tabindex="0">SIGN UP</a></li></ul><div class="AuthModal-surfWrapper" id="surfWrapper"></div><p><input type="checkbox"/>Keep Me Logged In</p></div><div class="AuthModal-Footer"></div></div></div></div><div class="App-containerClick"><div class="cnbcBrand" id="BrandPageWrapper"><div class="JumpLink-container"><a class="JumpLink-link" href="#MainContent">Skip Navigation</a></div><header class="GlobalNavigation-container" id="GlobalNavigation"><div class="CountdownClock-countdownContainer"><div class="CountdownClock-container" data-module="mps-slot" id="GlobalNavigation-CountdownClock"></div></div><div class="GlobalNavigation-globalNavigation"><div class="GlobalNavigation-gridContainer"><div class="GlobalNavigation-wrapper"><div class="branding-menu-brandingMenu"><a class="branding-menu-logo" href="//www.cnbc.com/world/"><img alt="logo" src="data:image/svg+xml;base64,..."/></a><div class="account-menu-accountMenu"><ul><li><a href="#">SIGN IN</a></li><li><a href="/pro/" title="pro_subscriber">Pro</a></li><li><a href="//www.cnbc.com/watchlist/" title="watchlist">Watchlist</a></li><li class="SignInMenu-makeit"><a href="/make-it/" title="makeit">Make It<span class="icon-offsite-arrow"></span></a></li><li><a href="/select/" title="select">Select<span class="icon-offsite-arrow"></span></a></li></ul><ul class="account-menu-editionMenu"><li><a alt="us_edition" href="/?region=usa">USA</a></li><li><a alt="international_edition" class="account-menu-underlineLabel" href="/world/">INTL</a></li></ul></div></div><div class="GlobalNavigation-desktopNavMenu"><div class="nav-menu-navMenu" id="nav-menu"><button class="nav-menu-desktopHamburger nav-menu-button"><span class="icon-menu"></span></button><a class="nav-menu-logoContainer" href="/"><img alt="logo" class="nav-menu-logo" src="data:image/svg+xml;base64,..."/></a><div class="nav-men ...
#   var measurementEnabled = true;
#   if (false) {
#     var optanonCookie =
#       document &&
#       document.cookie &&
#       document.cookie
#         .split(';')
#         .map((s) => s.trim())
#         .find((s) => s.startsWith('OptanonConsent'));
#     var measurementCategoryEnabledRegex = /groups=[^&]*%2C2%3A1/;
#     measurementEnabled = measurementCategoryEnabledRegex.test(optanonCookie);
#   };
#   window._comscore = [
#     {
#       c1: '2',
#       c2: '1000004',
#       options: { url_append: 'comscorekw=Markets|stocks' },
#       cs_ucfr: measurementEnabled ? 1 : 0
#     }
#   ];
# </script><script src="https://sb.scorecardresearch.com/beacon.js"></script><noscript><img alt="comscore" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=1000004&amp;cv=2.0&amp;cj=1"/></noscript><script charset="UTF-8">window.__s_data={"routing":{"locationBeforeTransitions":null},"navStatus":{"pageType":"page","articleTitle":"","hasNewsAlert":false,"hasLiveAlert":false,"hasCountDownClock":false,"hasPartnerExp":false,"articleSettings":{},"megaMenuToggleFlag":false,"isExpanded":false,"isIntraSiteLink":false},"dataByMarketBanner":{},"selectedMarketBanner":"","dataByMarketMover":{},"videoDataWithPosition":{"top":"-3000px","left":"-3000px","data":{},"videoAttributes":{}},"videoIsPreloader":{"isPreloader":true,"autoPlay":false,"firstVideoClickedOnPage":true},"videoPlayerInfo":{"position":"0","layout":"HIDDEN","playback":false,"adPlayback":false},"videoEventsInfo":{"position":0},"placeholderInfo":{"placeholderState":"INITIAL","replayVideo":false,"trackedIDs":[]},"videoRecommendationInfo":{"videoRecommendation":false},"videoEndCardInfo":{},"continuousPlayInfo":{"continuousToNextVideo":false,"playingIdx":0},"playBackInitiativeInfo":{"playBackInitiative":"Manual","isPlaylist":false},"dataByMarketTable":{},"dataByQuote":{},"metaTags":{"articleData":{},"pageData":{}},"dataByGDSMarketTable":{},"page":{"page":{"layout":[{"editable":false,"columns":[{"span":"full","editable":false,"modules":[{"name":"adHomepageTopBanner","source":null,"canChangeLayout":false,"canChangeSource":false,"serverRenderPolicy":null,"attributes":{},"options":null,"data":{"__typename":"asset"},"__typename":"module"}],"__typename":"column"}],"__typename":"layout"},{"editable":false,"columns":[{"span":"full","editable":false,"modules":[{"name":"pageHeader","source":"15839215","canChangeLayout":false,"canChangeSource":false,"serverRenderPolicy":null,"attributes":{"navEnabled":true},"options":{},"data":{"id":15839215,"brand":"cnbc","eyebrow":"stocks","color":"#000000","type":"franchise","subType":"section","url":"https:\u002F\u002Fwww.cnbc.com\u002Fstocks\u002F","adLogoText1":null,"adLogoText2":null,"tuneIn":null,"logo":null,"headerImage":null,"parent":{"id":102,"url":"https:\u002F\u002Fwww.cnbc.com\u002Fmarkets\u002F","eyebrow":"Markets","__typename":"sectionHierarchy"},"navigationUnsorted":[{"id":15839215,"eyebrow":"stocks","path":"\u002Fstocks\u002F","uri":"\u002Fstocks\u002F","type":"franchise","__typename":"navigation"},{"id":26272770,"eyebrow":"Dow 30","path":"\u002Fdow-30\u002F","uri":"\u002Fdow-30\u002F","type":"franchise","__typename":"navigation"},{"id":28141521,"eyebrow":"NASDAQ 100","path":"\u002Fnasdaq-100\u002F","uri":"\u002Fnasdaq-100\u002F","type":"franchise","__typename":"navigation"},{"id":33397842,"eyebrow":"Sectors","path":"\u002Fsectors\u002F","uri":"\u002Fsectors\u002F","type":"franchise","__typename":"navigation"}],"section":{"id":102,"color":"#000000","eyebrow":"Markets","type":"franchise","subType":"marketsection","adLogoText1":null,"adLogoText2":null,"tuneIn":null,"navigationUnsorted":[{"eyebrow":"Pre-Mkt","path":"\u002Fpre-markets\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"US","path":"\u002Fus-markets\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"EU","path":"\u002Feurope-markets\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"China","path":"\u002Fchina-markets\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"Asia","path":"\u002Fasia-markets\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"World","path":"\u002Fworld-markets\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"FX","path":"\u002Fcurrencies\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"Cryptocurrency","path":"\u002Fcryptocurrency\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"Commodities","path":"\u002Ffutures-and-commodities\u002F","type":"franchise","__typename":"navigation"},{"eyebrow":"Bonds","path":"\u002Fbonds\u002F","type":"franchise"," ...
#           function isES6Supported() {
#             'use strict';
#
#             if (typeof Symbol == 'undefined') return false;
#             try {
#               eval('class Foo {}');
#               eval('var bar = (x) => x+1');
#             } catch (e) { return false; }
#
#             return true;
#           }
#
#           function addScript(src) {
#             var s = document.createElement('script');
#             s.setAttribute('src', src);
#             document.head.appendChild(s);
#           }
#
#           if (!isES6Supported()) {
#             addScript('https://static-redesign.cnbcfm.com/dist/polyfill-bc59c001050d2fcbc2ea.js');
#           }
#         </script><script charset="UTF-8">
#                   var onLoadScripts = [{"text":"var __CNBC_META_DATA={\"layout\":[],\"aboutThisSection\":null,\"additionalSectionContentFormatted\":\"NA\",\"additionalSectionContentFormattedFull\":\"NA\",\"authorFormatted\":\"NA\",\"authorFormattedFull\":\"NA\",\"brand\":\"cnbc\",\"color\":\"#000000\",\"contentClassification\":[],\"cmsTemplate\":\"Topic Template\",\"creatorOverwrite\":null,\"creatorOverwriteFormatted\":\"NA\",\"dateFirstPublished\":\"2012-01-30T01:48:28+0000\",\"dateLastPublished\":\"2020-04-29T13:53:38+0000\",\"datePublished\":\"2012-01-30T01:48:28+0000\",\"description\":\"In-depth market analysis, real-time stock market data, research and earnings from CNBC.com. \",\"expires\":null,\"headline\":\"stocks\",\"id\":15839215,\"liveURL\":\"\u002Fstocks\u002F\",\"native\":false,\"pageName\":\"15839215|stocks\",\"premium\":false,\"projectContentFormatted\":\"NA\",\"projectContentFormattedFull\":\"NA\",\"projectTeamContentFormatted\":\"NA\",\"projectTeamContentFormattedFull\":\"NA\",\"relatedTagsFilteredFormatted\":\"NA\",\"relatedTagsFilteredFormattedFull\":\"NA\",\"sectionHierarchyFormatted\":\"markets|stocks\",\"sectionHierarchyFormattedFull\":\"markets|stocks\",\"seoTitle\":\"Stock Market News\",\"shortDateFirstPublished\":\"01\u002F29\u002F2012\",\"shortDateLastPublished\":\"04\u002F29\u002F2020\",\"shortDatePublished\":\"01\u002F29\u002F2012\",\"slug\":\"stocks\",\"sourceOrganizationFormatted\":\"NA\",\"sourceOrganizationFormattedFull\":\"NA\",\"subDomain\":\"https:\u002F\u002Fwww.cnbc.com\",\"subType\":\"section\",\"tagName\":\"stocks\",\"tagNameFormatted\":\"stocks\",\"tagNameFormattedFull\":\"stocks\",\"template\":\"SectionWithoutNative\",\"title\":\"stocks\",\"type\":\"franchise\",\"url\":\"https:\u002F\u002Fwww.cnbc.com\u002Fstocks\u002F\",\"canonicalUrlOverride\":null,\"vcpsId\":null,\"additionalSectionContent\":[],\"author\":[],\"featuredMedia\":null,\"projectContent\":[],\"projectTeamContent\":[],\"promoImage\":null,\"publisher\":{\"logo\":\"https:\u002F\u002Fsc.cnbcfm.com\u002Fapplications\u002Fcnbc.com\u002Fstaticcontent\u002Fimg\u002Fcnbc-hdr-logo2.png\",\"name\":\"CNBC\",\"__typename\":\"publisher\"},\"relatedContent\":[{\"headline\":\"Fast Money\",\"id\":15838499,\"tagName\":\"Fast Money\",\"tagNameFormatted\":\"fast money\",\"tagNameFormattedFull\":\"fast money\",\"type\":\"franchise\",\"__typename\":\"tag\"},{\"headline\":\"Mad Money with Jim Cramer\",\"id\":15838459,\"tagName\":\"Mad Money\",\"tagNameFormatted\":\"mad money\",\"tagNameFormattedFull\":\"mad money\",\"type\":\"franchise\",\"__typename\":\"tag\"}],\"relatedTags\":[],\"relatedTagsFiltered\":[],\"section\":{\"eyebrow\":\"Markets\",\"headline\":\"Markets\",\"id\":102,\"subType\":\"marketsection\",\"tagName\":\"Markets\",\"tagNameFormatted\":\"markets\",\"tagNameFormattedFull\":\"markets\",\"title\":\"Markets\",\"type\":\"franchise\",\"url\":\"https:\u002F\u002Fwww.cnbc.com\u002Fmarkets\u002F\",\"__typename\":\"franchise\"},\"sectionHierarchy\":[{\"id\":102,\"order\":2,\"tagName\":\"Markets\",\"tagNameFormatted\":\"markets\",\"tagNameFormattedFull\":\"markets\",\"__typename\":\"sectionHierarchy\"},{\"id\":15839215,\"order\":1,\"tagName\":\"stocks\",\"tagNameFormatted\":\"stocks\",\"tagNameFormattedFull\":\"stocks\",\"__typename\":\"sectionHierarchy\"}],\"sourceOrganization\":null,\"__typename\":\"page\",\"queryParams\":{}};var mpscall = {\"id\":15839215,\"slug\":\"stocks\",\"type\":\"franchise\",\"title\":\"stocks\",\"headline\":\"stocks\",\"pubdate\":1327888108,\"cat\":\"Markets|stocks\",\"adunits\":\"Top Banner|Box Rail|Box Inline|Logo|Mid Responsive|Countdown Clock|Sponsor Logo|Native Ultra Dense|Native Three Up|Native Ticker|Box Search\",\"dateline\":1327888108,\"nid\":15839215,\"site\":\"cnbc-web\",\"content_id\":15839215,\"path\":\"\u002Fid\u002F15839215\",\"cag[template]\":\"SectionWithoutNative\",\"is_sponsored\":0,\"is_premium\":0,\"cag[source]\":\"\",\"cag[brand]\":\"cnbc\",\"cag[creator]\":\"\",\"cag[company]\":\"\",\"cag[t ...
#
#                   if (window.addEventListener) window.addEventListener('load', loadScripts, false);
#                   else if (window.attachEvent) window.attachEvent('onload', loadScripts);
#
#                   function loadScripts() {
#                     (onLoadScripts || []).map(function(onLoadScript) {
#                       var script = document.createElement('script');
#
#                       Object.keys(onLoadScript).map(function(key) {
#                         const value = onLoadScript[key];
#                         if (key.includes('data-')) script.setAttribute(key, value);
#                         else script[key] = value;
#                       });
#
#                       document.body.appendChild(script);
#                     });
#                   }
#                 </script><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"356631dc7f","applicationID":"242029303","transactionName":"ZlAAYxBYW0BSW0FRDl8aI1QWUFpdHHZadQ5VQA5STVBbV1ZAGlEPVVAa","queueTime":0,"applicationTime":28,"atts":"ShcDFVhCSE4=","errorBeacon":"bam.nr-data.net","agent":""}</script></body></html>

# %%
coverpage_news = soup.find_all('a', class_='Card-title')
coverpage_news
# Out:
# [<a class="Card-title" href="https://www.cnbc.com/2020/04/29/these-retail-stocks-will-do-the-best-as-economy-reopens-bank-of-america-says.html" target=""><div>These retail stocks will do the best as economy reopens, Bank of America says</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/29/stock-market-live-updates-dow-futures-up-150-waiting-for-gdp-alphabet-surging.html" target=""><div>Stock market live updates: Stocks soar on Gilead treatment, Dow up 500, Alphabet leaps 9%</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/29/oil-etf-overseer-addresses-the-risks-of-investing-in-crude-based-funds.html" target=""><div>Oil ETF overseer addresses the risks of investing in crude-based funds</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/29/here-are-wall-streets-favorite-stocks-in-the-dow-right-now.html" target=""><div>Here are Wall Street's favorite stocks in the Dow right now</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/29/general-electric-q1-earnings-2020.html" target=""><div>GE says first-quarter revenue declined 8%, expects this quarter to be worse because of pandemic</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/29/chinas-battered-tesla-rival-nio-brushes-off-coronavirus-impact.html" target=""><div>China's battered Tesla rival Nio brushes off coronavirus impact, says the worst is over</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/29/livestreaming-drives-fraction-of-sales-in-coronavirus-hit-china-market.html" target=""><div>Livestreaming takes off in China, but it's not driving much sales in a virus-hit market</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/nucor-ceo-commits-to-dividend-expects-bottom-in-steel-prices-in-q2.html" target=""><div>Nucor CEO sticks by dividend, predicts steel price bottom in second quarter</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/cramer-lightning-round-i-have-no-long-case-for-gm.html" target=""><div>Cramer's lightning round: 'I have no long case for GM'</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/fed-could-give-more-insight-into-its-string-of-unprecedented-actions.html" target=""><div>Fed could give more insight into its string of unprecedented actions</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/jim-cramer-incredibly-strong-wall-street-month-is-based-on-hope.html" target=""><div>Wall Street's 'incredibly strong month' is based on 'hope,' Jim Cramer warns</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/stock-market-futures-open-to-close-news.html" target=""><div>Stocks soar after positive Gilead news on potential coronavirus treatment, Dow up 500 points</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/what-happened-to-the-stock-market-tuesday-tech-takes-wind-out-of-market-rally.html" target=""><div>Here's what happened to the stock market on Tuesday</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/alphabet-q1-2020-earnings-lookahead-what-two-traders-are-watching.html" target=""><div>Alphabet shares rise after Q1 revenue estimate beat — here's what two traders are watching</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/this-quality-at-reasonable-price-basket-from-goldman-is-expected-to-beat-the-market.html" target=""><div>This 'quality-at-reasonable-price' basket from Goldman is expected to beat the market</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/oil-producers-are-looking-for-storage-and-these-stocks-could-benefit-according-to-cfra.html" target=""><div>Oil producers are looking for storage and these stocks could benefit, according to CFRA</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/stocks-making-the-biggest-moves-midday-netflix-gap-bank-of-america-harley-davidson.html" target=""><div>Stocks making the biggest moves midday: Netflix, Gap, Bank of America, Harley-Davidson and more</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/stocks-you-want-to-own-when-economy-starts-to-reopen-goldman-says.html" target=""><div>These are the stocks you want to own when the economy starts to reopen, Goldman says</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/mnuchin-says-it-was-outrageous-for-the-lakers-other-such-businesses-to-take-small-business-loans.html" target=""><div>Treasury Secretary Mnuchin says it was 'outrageous' for the LA Lakers to take a small business loan</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/trading-oil-and-gas-etfs-after-diamond-offshore-bankruptcy-filing.html" target=""><div>How you can play oil ETFs after Diamond Offshore bankruptcy filing</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/oil-prices-could-go-negative-again-for-reasons-beyond-just-storage.html" target=""><div>Oil prices could go negative again for reasons beyond just storage</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/stock-market-today-live.html" target=""><div>Stock market live Tuesday: Stocks fall in volatile session, FANG in the red, retailers surge</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/caterpillar-cat-earnings-q1-2020.html" target=""><div>Caterpillar says first-quarter sales decline 21%, does not give 2020 outlook because of pandemic</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/28/china-cracks-down-on-fraud-and-tries-to-cleans-up-image-with-luckin-probe.html" target=""><div>China cracks down on fraud and tries to clean up image with Luckin probe</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/oil-news-wti-crude-brent-prices-today.html" target=""><div>Oil drops 3% in volatile session as storage capacity fears and weak demand weigh</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/nvidia-ceo-calls-mellanox-acquisition-a-homerun-deal.html" target=""><div>Nvidia completes 'homerun deal' after closing $7 billion acquisition of Mellanox</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/jim-cramer-mad-covid-19-index-of-stocks-to-invest-in-this-tricky-environment.html" target=""><div>Jim Cramer: Remember these stocks the 'next time the market rolls over'</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/cramer-lightning-round-i-would-be-a-buyer-of-slack.html" target=""><div>Cramer's lightning round: I would be a buyer of Slack</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/cramer-new-normal-is-less-investable.html" target=""><div>The 'new normal' is a lot less investable as states reopen, Jim Cramer says</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/saudi-arabia-buys-500-million-stake-in-coronavirus-hit-live-nation.html" target=""><div>Saudi Arabia buys $500 million stake in coronavirus-hit Live Nation, stock jumps nearly 10%</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/stock-market-futures-open-to-close-news.html" target=""><div>Stocks fall, Dow snaps 4-day winning streak as big tech shares slide</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/what-happened-to-the-stock-market-monday-hopes-of-reopenings-lift-stocks.html" target=""><div>Here's what happened to the stock market on Monday</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/avoid-stocks-with-most-exposure-to-small-business-goldman-says.html" target=""><div>These stocks have the most exposure to small businesses and should be avoided, Goldman says</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/as-states-reopen-these-retail-stocks-will-benefit-most-jpmorgan-says.html" target=""><div>As states reopen, these retail stocks will benefit most, JPMorgan says</div></a>,
#  <a class="Card-title" href="https://www.cnbc.com/2020/04/27/jeffrey-gundlach-says-a-retest-of-the-low-is-very-plausible-market-underestimating-social-unease.html" target=""><div>Jeffrey Gundlach is shorting the market, says a retest of the low 'very plausible'</div></a>]

# %%
coverpage_news = [c.get_text() for c in coverpage_news]
coverpage_news
# Out:
# ['These retail stocks will do the best as economy reopens, Bank of America says',
#  'Stock market live updates: Stocks soar on Gilead treatment, Dow up 500, Alphabet leaps 9%',
#  'Oil ETF overseer addresses the risks of investing in crude-based funds',
#  "Here are Wall Street's favorite stocks in the Dow right now",
#  'GE says first-quarter revenue declined 8%, expects this quarter to be worse because of pandemic',
#  "China's battered Tesla rival Nio brushes off coronavirus impact, says the worst is over",
#  "Livestreaming takes off in China, but it's not driving much sales in a virus-hit market",
#  'Nucor CEO sticks by dividend, predicts steel price bottom in second quarter',
#  "Cramer's lightning round: 'I have no long case for GM'",
#  'Fed could give more insight into its string of unprecedented actions',
#  "Wall Street's 'incredibly strong month' is based on 'hope,' Jim Cramer warns",
#  'Stocks soar after positive Gilead news on potential coronavirus treatment, Dow up 500 points',
#  "Here's what happened to the stock market on Tuesday",
#  "Alphabet shares rise after Q1 revenue estimate beat — here's what two traders are watching",
#  "This 'quality-at-reasonable-price' basket from Goldman is expected to beat the market",
#  'Oil producers are looking for storage and these stocks could benefit, according to CFRA',
#  'Stocks making the biggest moves midday: Netflix, Gap, Bank of America, Harley-Davidson and more',
#  'These are the stocks you want to own when the economy starts to reopen, Goldman says',
#  "Treasury Secretary Mnuchin says it was 'outrageous' for the LA Lakers to take a small business loan",
#  'How you can play oil ETFs after Diamond Offshore bankruptcy filing',
#  'Oil prices could go negative again for reasons beyond just storage',
#  'Stock market live Tuesday: Stocks fall in volatile session, FANG in the red, retailers surge',
#  'Caterpillar says first-quarter sales decline 21%, does not give 2020 outlook because of pandemic',
#  'China cracks down on fraud and tries to clean up image with Luckin probe',
#  'Oil drops 3% in volatile session as storage capacity fears and weak demand weigh',
#  "Nvidia completes 'homerun deal' after closing $7 billion acquisition of Mellanox",
#  "Jim Cramer: Remember these stocks the 'next time the market rolls over'",
#  "Cramer's lightning round: I would be a buyer of Slack",
#  "The 'new normal' is a lot less investable as states reopen, Jim Cramer says",
#  'Saudi Arabia buys $500 million stake in coronavirus-hit Live Nation, stock jumps nearly 10%',
#  'Stocks fall, Dow snaps 4-day winning streak as big tech shares slide',
#  "Here's what happened to the stock market on Monday",
#  'These stocks have the most exposure to small businesses and should be avoided, Goldman says',
#  'As states reopen, these retail stocks will benefit most, JPMorgan says',
#  "Jeffrey Gundlach is shorting the market, says a retest of the low 'very plausible'"]

# %% [markdown]
# ## 03. Combining Your Methods
# Now combine the methods defined above into a single method that allows you to get the text content of the elements of your choice within a given url.
#
#     `retrieve_text_url(url, element_tag, ...)`
#
# As previously, add this method to `scrapper.py` and test it below:

# %% [markdown]
# ## 04. Finalizing Your Module
# Now, add `__main__` section to your `scrapper.py`, allowing to run the script standalone via terminal by calling:
#
#     `python scrapper.py url element_tag`

# %% [markdown]
# ## 05. Scrapper Extensions
# Think of a scrapper extension that would increase its functionality. Some examples are given below:
#
#     Maybe it would be useful to also retrieve data from the sub-links within your elements? How would you do that?
#
#     Or maybe this could be done both more efficiently using a different package, e.g.: Scrapy?
#
#     What if you want to traverse a large list of webpages?
#
#     Maybe it is possible to get around the `robot security` problem that may arise when scrapping pages like Bloomberg news.
