# %% [markdown]
# _____________
# # 06. Modeling AddClicks - `Logistic Regression Example`
# The following notebook contains an example of add clicking prediction model using an advertising dataset.
# _______________
#
# <img src="img/logr.png" style="width: 1000px;"/>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading & Exploration

# %%
ad_data = pd.read_csv('data/advertising.csv', low_memory=False)

# %%
ad_data.head(3).T
# Out:
#                                                            0  \
# Daily Time Spent on Site                               68.95
# Age                                                       35
# Area Income                                          61833.9
# Daily Internet Usage                                  256.09
# Ad Topic Line             Cloned 5thgeneration orchestration
# City                                             Wrightburgh
# Male                                                       0
# Country                                              Tunisia
# Timestamp                                2016-03-27 00:53:11
# Clicked on Ad                                              0
#
#                                                            1  \
# Daily Time Spent on Site                               80.23
# Age                                                       31
# Area Income                                          68441.9
# Daily Internet Usage                                  193.77
# Ad Topic Line             Monitored national standardization
# City                                               West Jodi
# Male                                                       1
# Country                                                Nauru
# Timestamp                                2016-04-04 01:39:02
# Clicked on Ad                                              0
#
#                                                          2
# Daily Time Spent on Site                             69.47
# Age                                                     26
# Area Income                                        59785.9
# Daily Internet Usage                                 236.5
# Ad Topic Line             Organic bottom-line service-desk
# City                                              Davidton
# Male                                                     0
# Country                                         San Marino
# Timestamp                              2016-03-13 20:35:42
# Clicked on Ad                                            0

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
# Daily Time Spent on Site    1000 non-null float64
# Age                         1000 non-null int64
# Area Income                 1000 non-null float64
# Daily Internet Usage        1000 non-null float64
# Ad Topic Line               1000 non-null object
# City                        1000 non-null object
# Male                        1000 non-null int64
# Country                     1000 non-null object
# Timestamp                   1000 non-null object
# Clicked on Ad               1000 non-null int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# 75%              218.792500     1.000000        1.00000
# max              269.960000     1.000000        1.00000

# %%
sns.set_style('whitegrid')

# %%
ad_data['Age'].hist(bins=30)
plt.xlabel('Age')
# Out:
# Text(0.5,0,'Age')

# %%
sns.jointplot(data=ad_data, x='Age', y='Area Income')

# %%
sns.pairplot(ad_data)

# %%
sns.jointplot(data=ad_data, x='Age', y='Daily Time Spent on Site', color='red', kind='kde')

# %%
sns.jointplot(data=ad_data, x='Daily Time Spent on Site', y='Daily Internet Usage', color='red', kind='kde')

# %% [markdown]
# ### Feature Selection & Train Test Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
ad_data.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
all_features = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage', 'Male']]

# %%
train_data, test_data, train_labels, test_labels = train_test_split(
    all_features, ad_data['Clicked on Ad'], test_size=0.2, random_state=42)

# %%
[x.shape for x in (train_data, test_data, train_labels, test_labels)]
# Out:
# [(800, 5), (200, 5), (800,), (200,)]

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
model.fit(train_data, train_labels)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ## Inference

# %%
model.coef_, model.intercept_
# Out:
# (array([[-5.55704954e-02,  2.61911546e-01, -1.53274922e-05,
#          -2.70202278e-02,  1.79079055e-03]]), array([0.00552637]))

# %%
test_predictions = model.predict(test_data)

# %% [markdown]
# ## Evaluation (Precision | Recall | F1)
#
# <img src="img/pr3.png" style="width: 700px;"/>
#
# _____________
#
# <img src="img/pr2.png" style="width: 1000px;"/>
#
# ________
#
# <img src="img/pr.png" style="width: 1000px;"/>
#
# ________
#
# ***F1*** score combines both precision and recall by calculating their harmonic mean. Check this [gif](https://pmirla.github.io/assets/harmonic_mean.gif) for more info.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(test_labels, test_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.89        89
#            1       0.96      0.86      0.90       111
#
#    micro avg       0.90      0.90      0.90       200
#    macro avg       0.90      0.91      0.90       200
# weighted avg       0.91      0.90      0.90       200

# %%
print(confusion_matrix(test_labels, test_predictions))
# Out:
# [[85  4]
#  [16 95]]
